# %%
import pandas as pd
df1 = pd.read_excel('/content/drive/MyDrive/Colab Notebooks/Monitor subsidies 2021 vs 2022.xlsx')
df2 = pd.read_excel('/content/drive/MyDrive/Colab Notebooks/samevatting_subsidie.xlsx')

# %%
df1.head(2)
# Out:
#   Subsidieregelingen en beleidsregels op grond van de Kaderwet VWS-subsidies (Bedragen x €1.000)  \
# 0  Kaderregeling VWS-subsidies / Kaderregeling su...
# 1  Specifieke uitkering lokale preventieakkoorden...
#
#        2021 Totaal begroot       2022  Totaal begroot.1 Directies
# 0  113076.0            NaN        NaN               NaN       NaN
# 1    7100.0           8000  6195.2695          6893.888        PG

# %%
df1.columns
# Out:
# Index(['Subsidieregelingen en beleidsregels op grond van de Kaderwet VWS-subsidies (Bedragen x €1.000)',
#                                                                                                    2021,
#                                                                                        'Totaal begroot',
#                                                                                                    2022,
#                                                                                      'Totaal begroot.1',
#                                                                                             'Directies'],
#       dtype='object')

# %%
df2.head(2)
# Out:
#                                  Rijlabels  Som van Orig. bedrag (TV)2  \
# 0              331241 Verlening kncv 2021                    430.82663
# 1  3e Bevoorschotting SOV-Oekraïne Trek.2                   2000.00000
#
#    Som van Bedrag totaal (TV)2
# 0                    365.45649
# 1                  16000.00000

# %%
import numpy as np
df2["sub_noted_in_monitor"] = list(map(lambda x: "ja" if x else "", np.in1d(df2['Rijlabels'], df1['Subsidieregelingen en beleidsregels op grond van de Kaderwet VWS-subsidies (Bedragen x €1.000)'])))

# %%
import numpy as np
df2["ori_bedrag_noted_in_monitor"] = list(map(lambda x: "ja" if x else "", np.in1d(df2['Som van Orig. bedrag (TV)2'], df1[2022])))

# %%
df2["Tot_bedrag_noted_in_monitor"] = list(map(lambda x: "ja" if x else "", np.in1d(df2['Som van Bedrag totaal (TV)2'], df1['Totaal begroot.1'])))

# %%
df2.to_excel('test.xlsx')
